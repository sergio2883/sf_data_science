# %%
import game_v2
# Out:
# Количество попыток: 1516

# %%
game_v2.score_game(game_v2.random_predict)
# Out:
# Ваш алгоритм угадывает число в среднем за: 731 попыток
# 731

# %% [markdown]
# # Игра угадай число

# %%
from game_v2 import score_game, random_predict

# %% [markdown]
# ## Угадываем рандомно:

# %%
score_game(random_predict) #вызов функции
# Out:
# Ваш алгоритм угадывает число в среднем за: 731 попыток
# 731

# %%
n = 10
z = n
n = 5

# %%
x = 65
